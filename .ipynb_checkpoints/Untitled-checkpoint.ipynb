# %%
import pandas as pd

# %%
df1=pd.read_csv('my_submission.csv')
df1.head(418)
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
df2=pd.read_csv('KNNsubmission.csv')
df2.head(418)
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]

# %%
df3=pd.read_csv('RFsubmission.csv')
df3.head(418)
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
for col in df:
    df[col] = df[col].sort_values(ignore_index=True)

# %%
df.dropna(axis=0, how='all',inplace=True)

# %%
df.drop(['13','14','15','16'],axis=1,inplace=True)

# %%
df.to_excel('words.xlsx')
